# %%
# Research for project relating to Montreal

# %%
import geopandas as gpd # for geospatial data handling
import pandas as pd
import osmnx as ox # for handling data from OpenStreetMap (osm) with the help of networkX (nx)
import contextily as cx # for plotting
import matplotlib.pyplot as plt # for plotting
from pyproj import CRS # for more advanced CRS modifications and transformations
from shapely.geometry import Polygon

# %%
# Define the city name or bounding box
city = 'Montreal, Canada'

# Retrieve the road network graph for driving, walking, and biking
drive_graph = ox.graph_from_place(city, network_type='drive')


# Get the number of nodes and edges for each mode of transportation
drive_nodes_count = len(drive_graph.nodes)
drive_edges_count = len(drive_graph.edges)


# Print the results
print("Drive: Yes")
print("- Number of nodes:", drive_nodes_count)
print("- Number of edges:", drive_edges_count)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# Drive: Yes
# - Number of nodes: 19532
# - Number of edges: 49023

# %%
# Define the city name or bounding box
city = 'Montreal, Canada'

# Retrieve the road network graph for driving, walking, and biking
bike_graph = ox.graph_from_place(city, network_type='bike')

# Get the number of nodes and edges for each mode of transportation
bike_nodes_count = len(bike_graph.nodes)
bike_edges_count = len(bike_graph.edges)

# Print the results
print("Bike: Yes")
print("- Number of nodes:", bike_nodes_count)
print("- Number of edges:", bike_edges_count)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# Bike: Yes
# - Number of nodes: 54834
# - Number of edges: 138313

# %%
# Define the city name or bounding box
city = 'Montreal, Canada'

# Retrieve the road network graph for driving, walking, and biking
walk_graph = ox.graph_from_place(city, network_type='walk')

# Get the number of nodes and edges for each mode of transportation
walk_nodes_count = len(walk_graph.nodes)
walk_edges_count = len(walk_graph.edges)

# Print the results

print("Walk: Yes")
print("- Number of nodes:", walk_nodes_count)
print("- Number of edges:", walk_edges_count)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# Walk: Yes
# - Number of nodes: 144768
# - Number of edges: 465390

# %%
mon_pois = ox.geometries_from_place(
    "Montreal, Canada", tags={"amenity": True}
)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# /opt/conda/lib/python3.9/site-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# /opt/conda/lib/python3.9/site-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):

# %%
len(mon_pois)
# Out:
# 25403

# %%
len(mon_pois['amenity'].value_counts())
# Out:
# 131

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display the full list of value counts for the 'amenity' column
print(mon_pois['amenity'].value_counts())
# Out:
# parking                    4734
# bench                      4314
# bicycle_parking            3123
# restaurant                 1868
# waste_basket               1116
# parking_space               792
# charging_station            777
# cafe                        738
# fast_food                   577
# school                      563
# post_box                    460
# place_of_worship            453
# drinking_water              419
# taxi                        350
# loading_dock                308
# parking_entrance            282
# vending_machine             272
# bar                         263
# bank                        262
# social_facility             232
# telephone                   223
# pharmacy                    222
# shelter                     207
# toilets                     191
# fuel                        179
# bicycle_rental              173
# dentist                     139
# kindergarten                135
# childcare                   121
# clinic                      120
# fountain                    108
# pub                          98
# community_centre             96
# library                      78
# ice_cream                    76
# post_office                  74
# atm                          74
# recycling                    72
# public_bookcase              70
# lounger                      63
# theatre                      62
# bicycle_repair_station       52
# car_wash                     51
# fire_station                 50
# hospital                     47
# car_rental                   42
# university                   41
# college                      39
# police                       38
# car_sharing                  36
# table                        30
# doctors                      30
# driving_school               29
# arts_centre                  26
# bureau_de_change             26
# veterinary                   24
# nightclub                    21
# dojo                         20
# cinema                       19
# social_centre                19
# townhall                     19
# public_building              15
# waste_disposal               15
# marketplace                  14
# studio                       13
# bus_station                  11
# events_venue                 10
# smoking_area                 10
# money_transfer               10
# motorcycle_parking           10
# courthouse                    9
# ferry_terminal                8
# trolley_bay                   8
# coworking_space               6
# prep_school                   6
# compressed_air                6
# research_institute            5
# bbq                           5
# training                      5
# stripclub                     4
# music_school                  4
# internet_cafe                 4
# shower                        4
# dressing_room                 4
# language_school               4
# grave_yard                    4
# public_bath                   3
# food_court                    3
# watering_place                3
# water_point                   3
# monastery                     3
# clock                         3
# crematorium                   2
# spa                           2
# student_accommodation         2
# letter_box                    2
# lavoir                        2
# weighbridge                   2
# ranger_station                2
# prison                        2
# disused                       2
# casino                        1
# post_depot                    1
# locker                        1
# daycare                       1
# construction                  1
# planetarium                   1
# city_building                 1
# c                             1
# social_center                 1
# vicarage                      1
# karaoke_box                   1
# audiologist                   1
# animal_training               1
# feeding_place                 1
# animal_shelter                1
# vehicle_inspection            1
# grocery                       1
# boat_rental                   1
# waste_basket;telephone        1
# convenience                   1
# la                            1
# restaurant;bar                1
# hookah_lounge                 1
# animal_boarding               1
# ramp                          1
# grit_bin                      1
# bicycle_trailer_sharing       1
# conference_centre             1
# nursing_home                  1
# biergarten                    1
# Name: amenity, dtype: int64

# %%
# Assuming 'gdf' is your GeoDataFrame containing POIs and 'amenity_counts' is the counts of each amenity type
amenity_counts = mon_pois['amenity'].value_counts()
N = 10  # Number of top amenities to consider
top_amenities = amenity_counts.head(N).index  # Get the top N amenity types

# Create a color map for different amenities
colors = plt.cm.tab10.colors

# Plot each top amenity type with a different color
for i, amenity_type in enumerate(top_amenities):
    amenity_data = mon_pois[mon_pois['amenity'] == amenity_type]
    amenity_data.plot(color=colors[i], label=amenity_type)
    plt.legend()

plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# /opt/conda/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
mon_pois.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Define the city and retrieve its boundary
city = "Montreal, Canada"
graph = ox.graph_from_place(city)
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
# Get neighborhood boundaries
neighborhoods = ox.geometries_from_place(city, tags={"place": "neighbourhood"})

# Save as GeoPackage
neighborhoods.to_file("montreal_neighborhoods.gpkg", driver="GPKG")
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 # Define the city and retrieve its boundary
#       2 city = "Montreal, Canada"
# ----> 3 graph = osmnx.graph_from_place(city)
#       5 # Get neighborhood boundaries
#       6 neighborhoods = osmnx.geometries_from_place(city, tags={"place": "neighbourhood"})
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/graph.py:343, in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, buffer_dist, clean_periphery, custom_filter)
#     340 utils.log("Constructed place geometry polygon(s) to query API")
#     342 # create graph using this polygon(s) geometry
# --> 343 G = graph_from_polygon(
#     344     polygon,
#     345     network_type=network_type,
#     346     simplify=simplify,
#     347     retain_all=retain_all,
#     348     truncate_by_edge=truncate_by_edge,
#     349     clean_periphery=clean_periphery,
#     350     custom_filter=custom_filter,
#     351 )
#     353 utils.log(f"graph_from_place returned graph with {len(G)} nodes and {len(G.edges)} edges")
#     354 return G
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/graph.py:436, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     434 # simplify the graph topology
#     435 if simplify:
# --> 436     G_buff = simplification.simplify_graph(G_buff)
#     438 # truncate graph by original polygon to return graph within polygon
#     439 # caller wants. don't simplify again: this allows us to retain
#     440 # intersections along the street that may now only connect 2 street
#     441 # segments in the network, but in reality also connect to an
#     442 # intersection just outside the polygon
#     443 G = truncate.truncate_graph_polygon(G_buff, polygon, retain_all, truncate_by_edge)
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/simplification.py:241, in simplify_graph(G, strict, remove_rings)
#     238 all_edges_to_add = []
#     240 # generate each path that needs to be simplified
# --> 241 for path in _get_paths_to_simplify(G, strict=strict):
#     242
#     243     # add the interstitial edges we're removing to a list so we can retain
#     244     # their spatial geometry
#     245     path_attributes = dict()
#     246     for u, v in zip(path[:-1], path[1:]):
#     247
#     248         # there should rarely be multiple edges between interstitial nodes
#     249         # usually happens if OSM has duplicate ways digitized for just one
#     250         # street... we will keep only one of the edges (see below)
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/simplification.py:182, in _get_paths_to_simplify(G, strict)
#     163 """
#     164 Generate all the paths to be simplified between endpoint nodes.
#     165
#    (...)
#     179 path_to_simplify : list
#     180 """
#     181 # first identify all the nodes that are endpoints
# --> 182 endpoints = set([n for n in G.nodes if _is_endpoint(G, n, strict=strict)])
#     183 utils.log(f"Identified {len(endpoints)} edge endpoints")
#     185 # for each endpoint node, look at each of its successor nodes
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/simplification.py:182, in <listcomp>(.0)
#     163 """
#     164 Generate all the paths to be simplified between endpoint nodes.
#     165
#    (...)
#     179 path_to_simplify : list
#     180 """
#     181 # first identify all the nodes that are endpoints
# --> 182 endpoints = set([n for n in G.nodes if _is_endpoint(G, n, strict=strict)])
#     183 utils.log(f"Identified {len(endpoints)} edge endpoints")
#     185 # for each endpoint node, look at each of its successor nodes
#
# File /opt/conda/lib/python3.9/site-packages/osmnx/simplification.py:46, in _is_endpoint(G, node, strict)
#      44 neighbors = set(list(G.predecessors(node)) + list(G.successors(node)))
#      45 n = len(neighbors)
# ---> 46 d = G.degree(node)
#      48 # rule 1
#      49 if node in neighbors:
#      50     # if the node appears in its list of neighbors, it self-loops
#      51     # this is always an endpoint.
#
# File /opt/conda/lib/python3.9/site-packages/networkx/classes/reportviews.py:431, in DiDegreeView.__call__(self, nbunch, weight)
#     429     if nbunch in self._nodes:
#     430         if weight == self._weight:
# --> 431             return self[nbunch]
#     432         return self.__class__(self._graph, None, weight)[nbunch]
#     433 except TypeError:
#
# File /opt/conda/lib/python3.9/site-packages/networkx/classes/reportviews.py:635, in DiMultiDegreeView.__getitem__(self, n)
#     633 preds = self._pred[n]
#     634 if weight is None:
# --> 635     return sum(len(keys) for keys in succs.values()) + sum(
#     636         len(keys) for keys in preds.values()
#     637     )
#     638 # edge weighted graph - degree is sum of nbr edge weights
#     639 deg = sum(
#     640     d.get(weight, 1) for key_dict in succs.values() for d in key_dict.values()
#     641 ) + sum(
#     642     d.get(weight, 1) for key_dict in preds.values() for d in key_dict.values()
#     643 )
#
# File /opt/conda/lib/python3.9/site-packages/networkx/classes/reportviews.py:635, in <genexpr>(.0)
#     633 preds = self._pred[n]
#     634 if weight is None:
# --> 635     return sum(len(keys) for keys in succs.values()) + sum(
#     636         len(keys) for keys in preds.values()
#     637     )
#     638 # edge weighted graph - degree is sum of nbr edge weights
#     639 deg = sum(
#     640     d.get(weight, 1) for key_dict in succs.values() for d in key_dict.values()
#     641 ) + sum(
#     642     d.get(weight, 1) for key_dict in preds.values() for d in key_dict.values()
#     643 )
#
# KeyboardInterrupt:

# %%
# Read the GeoPackage file
montreal_neighborhoods = gpd.read_file("montreal_neighborhoods.gpkg")

# Plot the neighborhood boundaries
fig, ax = plt.subplots(figsize=(10, 8))
montreal_neighborhoods.plot(ax=ax, edgecolor='black', facecolor='none')
ax.set_title('Montreal Neighborhoods')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
import folium

# Create a map centered around Montreal
montreal_map = folium.Map(location=[45.5017, -73.5673], zoom_start=11)

# Add neighborhood boundaries to the map
for idx, row in montreal_neighborhoods.iterrows():
    folium.GeoJson(row['geometry']).add_to(montreal_map)

# Display the map
montreal_map.save("montreal_neighborhoods_map.html")

# %%
# looking at splitting the city into neighbourhoods

# %%
# Define the city of Montreal
city = ox.geocode_to_gdf("Montreal, Canada")
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
# Get the street network for Montreal
G = ox.graph_from_place("Montreal, Canada", network_type="all")
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
# Get neighborhood boundaries for Montreal
neighborhoods = ox.geocode_to_gdf("Montreal, Canada")
# Out:
# /opt/conda/lib/python3.9/site-packages/osmnx/geocoder.py:110: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gdf = gdf.append(_geocode_query_to_gdf(q, wr, by_osmid))

# %%
# Plot the neighborhood boundaries
ox.plot_footprints(ox.project_gdf(neighborhoods))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
# Create subgraphs for each neighborhood
neighborhood_subgraphs = {}

# Adjust parameters for graph creation
graph_params = {
    "network_type": "drive",  # Consider using a simpler network type if possible
    "clean_periphery": True
}

for index, neighborhood in neighborhoods.iterrows():
    polygon = neighborhood['geometry']
    
    # Simplify the polygon if needed
    simplified_polygon = polygon.simplify(0.001, preserve_topology=False)
    
    # Create a bounding box if needed
    # bounding_box = Polygon(polygon.bounds)
    
    subgraph = ox.graph_from_polygon(simplified_polygon, **graph_params)
    neighborhood_subgraphs[index] = subgraph

# %%
# Iterate through the subgraphs and plot them
for index, subgraph in neighborhood_subgraphs.items():
    fig, ax = ox.plot_graph(subgraph, show=False, close=False)
    ax.set_title(f"Neighborhood {index} Subgraph")
    plt.show()

# %%
# Iterate over neighborhoods DataFrame to print out indices and any available information
for index, neighborhood in neighborhoods.iterrows():
    print(f"Neighborhood Index: {index}")
    print(neighborhood)  # Print out the entire row for the neighborhood
    print("\n")
# Out:
# Neighborhood Index: 0
# geometry        POLYGON ((-73.9741567 45.4664326, -73.937487 4...
# bbox_north                                               45.70479
# bbox_south                                              45.410076
# bbox_east                                              -73.474295
# bbox_west                                              -73.974157
# place_id                                                 21186446
# osm_type                                                 relation
# osm_id                                                    1634158
# lat                                                     45.503182
# lon                                                    -73.569806
# class                                                    boundary
# type                                               administrative
# place_rank                                                     16
# importance                                               0.711736
# addresstype                                                  city
# name                                                     Montreal
# display_name    Montreal, Urban agglomeration of Montreal, Mon...
# Name: 0, dtype: object

# %%
neighborhoods.head()
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-73.97416 45.46643, -73.93749 45.451...    45.70479   45.410076
#
#    bbox_east  bbox_west  place_id  osm_type   osm_id        lat        lon  \
# 0 -73.474295 -73.974157  21186446  relation  1634158  45.503182 -73.569806
#
#       class            type  place_rank  importance addresstype      name  \
# 0  boundary  administrative          16    0.711736        city  Montreal
#
#                                         display_name
# 0  Montreal, Urban agglomeration of Montreal, Mon...
